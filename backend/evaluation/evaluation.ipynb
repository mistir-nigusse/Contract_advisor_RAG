# %%
import pandas as pd

# %%
file_path = "../data/evaluation_results.csv"
df = pd.read_csv(file_path)
df
# Out:
#                                              question  \
# 0   Under what circumstances and to what extent th...
# 1   Does the Buyer need the Sellers’ consent in th...
# 2   Would the Sellers be responsible if after the ...
# 3                      How much is the escrow amount?
# 4   Is escrow amount greater than the Retention Am...
# 5                  What is the purpose of the escrow?
# 6   May the Escrow Amount serve as a recourse for ...
# 7            Are there any conditions to the closing?
# 8   Are Change of Control Payments considered a Se...
# 9   Would the aggregate amount payable by the Buye...
# 10  Does the Buyer need to pay the Employees Closi...
# 11  Does any of the Sellers provide a representati...
# 12  Is any of the Sellers bound by a non-competiti...
# 13  Whose consent is required for the assignment o...
#
#                                                answer  \
# 0   Each Seller is responsible for a breach of rep...
# ...
